# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd
df = pd.read_csv('pokemon_data.csv')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#import pandas as pd
#df_csv = pd.read_csv('pokemon_data.csv')
#print(df_csv)
#df_xlsx = pd.read_excel('pokemon_data.xlsx')
#print(df_xlsx.head(3))
#df = pd.read_csv('pokemon_data.txt', delimiter='\t')
#print(df.head(5))

# %%
#import numpy as np

#arr = np.array([1, 2, 3, 4, 5])

#print(arr)

# %%
#read headers
#print(df.columns)
# read each column

#print(df['Name'][1])
#read each row
#print(df[['Name','Type 1','HP']])
df.columns
#print(df.iloc[2,1])
#for index, row in df.iterrows():
    #print(index, row['Name'])  #only name row
df.loc[df['Type 1']=="Fire"] #type1 equal fire
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.to_csv('modified.txt', index=False, sep='\t')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.describe()
#df.sort_values('Name',ascending=False)  #decending order of name
df.sort_values(['Type 1', 'HP'],ascending=[1,0])  #first is ascending and 2nd is decending
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] +df['Sp. Atk']+ df['Sp. Def'] + df['Speed']
#df = df.drop(columns=['Total']) #delete total column
df['Total'] = df.iloc[:, 4:9].sum(axis=1) #another way of total
cols = list(df.columns.values)
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]
#df = df[['Total'],'HP','Defense']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    273  45      49       49
# 1  2                Ivysaur  Grass  Poison    345  60      62       63
# 2  3               Venusaur  Grass  Poison    445  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    545  80     100      123
# 4  4             Charmander   Fire     NaN    244  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#filtering data
import pandas as pd
import re  #regular expressions
df = pd.read_csv('pokemon_data.csv')
#df.loc[df['Type 1'] == 'Grass']  #grass only
#df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]  #grass and poison
#df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]  # | is or
#new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] >60)]
#new_df.to_csv('filtered.csv')
#new_df = new_df.reset_index()
#new_df.reset_index(drop=True, inplace=True)
#new_df
#df.loc[df['Name'].str.contains('Mega')] #word contain mega
#df.loc[~df['Name'].str.contains('Mega')]  #not mega
#df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I, regex=True)] #ignore the value captital letter
#df.loc[df['Name'].str.contains('pi[a-z]*',flags=re.I, regex=True)]  #* means zero or more filtered the word contain pi
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I, regex=True)]  #^ means start with Pi
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
#conditional changes

#df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

#df = pd.read_csv('pokemon_data.csv')
#df
#df.loc[df['Total'] > 500, ['Generation','Legendary']] = 'TEST VALUE'
#df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']
#df
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#aggregate statistics(group by)
import pandas as pd
df = pd.read_csv('modified.csv')
df.groupby(['Type 2']).mean()
#df.groupby(['Type 1']).sort_values('Defense', ascending=False)
#df.groupby(['Type 1']).sum()
#df.groupby(['Type 1']).count()
#df['count'] =1

#df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
# #### Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)
for df in pd.read_csv('modified.csv', chunksize=5):
    #print("CHUNK DF")
    #print(df)
    results= df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])

    print(new_df)
# Out:
#        # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire   1    1    NaN      0  1      1       1       1       1     1
# Grass  4    4    NaN      4  4      4       4       4       4     4
#
#       Generation Legendary
# Fire           1         1
# Grass          4         4
#        # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire   1    1    NaN      0  1      1       1       1       1     1
# Grass  4    4    NaN      4  4      4       4       4       4     4
# Fire   4    4    NaN      3  4      4       4       4       4     4
# Water  1    1    NaN      0  1      1       1       1       1     1
#
#       Generation Legendary
# Fire           1         1
# Grass          4         4
# Fire           4         4
# Water          1         1
#        # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire   1    1    NaN      0  1      1       1       1       1     1
# ...
